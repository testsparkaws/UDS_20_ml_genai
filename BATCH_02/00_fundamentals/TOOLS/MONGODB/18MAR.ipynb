# %%
## MOngDB ATLAS

# %%
## Create Project: mongo-demo

## 1. Free 
## 2. M10
## 3. FLEX

# %%
### Add Your IP Address to the project

# %%
### Creat a Database User 
## Choose a connection Method 
## Select Driver >> Python

# %%
## Create a Database
## Defaut We have admin / local DB 
## Create a Database >> right click on
## name: ultimate-data-science
## Collections :: Tables( dummy0)
## Add a Data

# %%
## Adding a Document 
## DICT / JSON 
## Insert a Document 
{
 "id": {},
 "user_name": "raj"
}

# %%
### FINAL STEPS ####
# 1. Create Project 
# 2. Create User & Password
# 3. Inside that we created the cluster 
# 4. We need to create a collections

# %%
## Relational VS NON-Relational DB

# %%
#!pip install "pymongo[srv]"
