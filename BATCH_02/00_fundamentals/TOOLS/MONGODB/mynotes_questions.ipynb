# %%
### Creating Cluster in MongoDB
'''
First sign up/sign in
- Create a project
- Create cluster -- > it is like server
    - choose service provider, region, and choose "free" option for exploring and learning.
    - click deployment
- Connect to cluster
    1. Setup connection security:
        - Add a connection ip address
        - Create database user --> provide username and password
    2. Choose a connect method
        -  Select driver(python) and version(keep given default)
        -  Install your driver  --> installation command will be given
        -  Add your connection string into your application code -> Here we will get url (need to fill username, and password of database)

    - Save both, installation command and url for connection
    - Now with the help of "data explorer" option (On left side of screen) we can connect to cluster and create database, collection
'''
