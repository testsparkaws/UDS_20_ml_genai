# %%
## What is System.path.append() whey we do it ?
## How to store everything in Database

# %%
### TO DO #############
# Use .env file

# %% [markdown]
# ## st.text_area()
#  * height

# %%
## text_area() --> height

# %%
## add this line(PyMyPDF==1.27.2.2) into pyproject.toml and then to 

# uv sync

# %%
import pymupdf

# %%
a = "hello"
b = ["he","ll","o"]

a.join(b)
# Out:
# 'hehellollhelloo'

# %%
## Unpacking
a = (1,2,3,4)
a
# Out:
# (1, 2, 3, 4)

# %%
print(*a)
b,c,d,e = a
print(b)
print(c)
print(d)
print(e)
# Out:
# 1 2 3 4
# 1
# 2
# 3
# 4
