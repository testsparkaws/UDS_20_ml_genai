# %%
## Python Project - Day 1

# %% [markdown]
# * Data Visualization
# * Python
# * Database
# * Streamlit
# * OOP

# %% [markdown]
# ## Future Goals :

# %%
## DocManager
# cd docManager 
#
## python -m venv 
## venv/Scripts/activate
## OR 
## uv pin python 3.14.3 
## uv init
## uv sync #

# %%
## Write testcase as well in this project 


can u please minimize the explored

# %%
### Usecase >>> can we get one more usecase without codebase

# %%
select count(current_page) from document where docid = ?

# %%
id = (1, )
print(type(id))
# Out:
# <class 'tuple'>

# %%
rerun() --> when we want to reset the sesion and run the code from the beginning.

# %%
#pip install -r requirements.txt


git add . && git commit -m "final commit" 
git push origin main
