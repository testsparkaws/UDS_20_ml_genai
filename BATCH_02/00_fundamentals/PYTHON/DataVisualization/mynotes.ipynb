# %% [markdown]
# I can see all the notes clearly. Let me build a comprehensive, beautiful PDF for these two sessions.Your PDF is ready! Here's what's inside across **10 pages**:
#
# **📄 Session 7 — 01 March 2026 (Data Visualization 1)**
# - Why visualize? (240 data points analogy — phone numbers vs faces)
# - 6 Principles of Good Visualization (clarity, scale, minimalism, labeling, color, correct chart)
# - **Scatter Plot** — with sample data table, dashed crosshair annotation
# - **Line Chart** — revenue over 12 months with trend line
# - **Bar Plot** — product vs sales comparison
# - **Stacked Bar Plot** — food vs body care sales layered
# - **Pie Chart** — A:70%, B:10%, C:20% with actual pie rendering
# - **Box/Whisker Plot** — fully annotated (min, Q1, median, Q3, max, IQR, outliers)
# - **groupby()** — split→apply→combine diagram with salary example
#
# **📄 Session 8 — 07 March 2026 (Viz 2 + Seaborn)**
# - Google Colab intro, session agenda
# - **random_state / seed** — reproducibility diagram with postman analogy
# - **Matplotlib Subplots** — 2×2 grid diagram, axes[row][col] access pattern
# - **Histogram** — 100 invoices, 10 bins, frequency counts visualized
# - **KDE (Kernel Density Estimate)** — smoothed curve, density vs probability explained
# - **Correlation** — positive (money↑ investment↑) vs negative (marks↑ rank↓) scatter plots
# - **AI-Assisted Workflow** — ChatGPT/Gemini → doc→coding→problem→solution
# - **Industry overview** — Service-based vs Product-based companies
#
# **📋 Quick Reference Table** — 20 Matplotlib/Seaborn functions with usage guide

# %% [markdown]
# # **DAY1**

# %%
## Day1 - Topic Covered ####
'''
  * df = pd.concat([df_1, df_2], ignore_index=True)
  * df = read_excel(path, sheet_name=sheet_name) 
  * df.info()
  * df.columns

  * monthly_revenue = df.groupby('Month')['Revenue'].sum()
  * df.sum()
'''

## 2.Cleaning & Feature Engineering
'''
  * df = df.dropna(subset=['Customer ID'])
  * df = df[~df['Invoice'].astype(str).str.startswith('C')]
  * df = df[df['Price'] > 0 ]

  # Add new Features 
  df['Revenue'] = df['Quantity'] * df['Price']
  df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
  df['Month'] = df['InvoiceDate'].dt.to_period('M').astype(str)

'''
# Out:
# "\n  * df = df.dropna(subset=['Customer ID'])\n  * df = df[~df['Invoice'].astype(str).str.startswith('C')]\n  * df = df[df['Price'] > 0 ]\n\n  # Add new Features \n  df['Revenue'] = df['Quantity'] * df['Price']\n  df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])\n  df['Month'] = df['InvoiceDate'].dt.to_period('M').astype(str)\n\n"

# %% [markdown]
# ### **Matplotlib**

# %% [markdown]
# - matplotlib is a powerful 2D plotting library in Python.
#
# - It allows you to create publication-quality figures in a variety of formats (PNG, SVG, PDF, etc.).
#
# - Commonly used module: matplotlib.pyplot, often imported as plt.
#
#
# ### **Why Use Matplotlib?**
#
# - Core plotting engine behind libraries like Seaborn and Pandas plots.
#
# - Works with NumPy and Pandas natively.
#
# - Gives you low-level control of every visual element (useful for fine-tuning).

# %%
# Plot line --> plt.plot()
plt.plot(monthly_revenue.index, monthly_revenue.values, marker='o')
# | Marker Symbol | Description     |
# | ------------- | --------------- |
# | `'o'`         | Circle          |
# | `'.'`         | Point           |
# | `','`         | Pixel           |
# | `'x'`         | X               |
# | `'+'`         | Plus            |
# | `'s'`         | Square          |
# | `'D'`         | Diamond         |
# | `'^'`         | Upward triangle |

# %%
#print(plt.style.available)

# %%
# plt.style.use('classic')
# plt.style.use('ggplot')

# plt.figure(figsize=(12,6), facecolor='white')

# %% [markdown]
# ## **COMMON CODE**

# %%
### What is Matplotlib ########

plt = None 

# Create a canvas using width and height, inches
plt.figure(figsize=(12, 6))


# title of the plot
plt.title('<TITLE>')

# X-axis label
plt.xlabel('<X_lable>')

# Y-axis label
plt.ylabel('Y_lable')

# rotate x labels
plt.xticks(rotation=45)
plt.yticks(rotation=45)

# Fit layout, prevents label clipping
plt.tight_layout()

# Show grid
plt.grid(True) 

# show the plot window or render the figure
plt.show()

# %% [markdown]
# ## **line Plot**

# %%
# 1. data.plot()

# %% [markdown]
# # **DAY2: SEABORN**

# %%
## Scatter Plot: Relationship Between Quantity & Revenue
'''
plt.scatter(
    sample_df['Quantity'], 
    sample_df['Revenue'], 
    alpha=0.5, 
    color = 'purple'
)
'''

# %%
# 2. Subplots: Multiple charts in one figure

#plt.figure(figsize=(8,5))
#fig , axs = plt.subplots(nrows = 2, ncols = 1, figsize=(10,8), sharex=True)

## REvenue Plot 
#axs[0].plot(monthly_revenue.index, monthly_revenue.values, marker='o', color='blue', label = 'Revenue-label')

# %%
## 3. Saving and Exporting Figures 
# plt.savefig("monthly_revenue.png", dpi=300)

# %% [markdown]
# ### **Seaborn: High-Level Statistical Data Visualization**
#
# Seaborn is a powerful Python visualization library built on top of Matplotlib and integrated with pandas. It simplifies many common tasks like:
#
# - Statistical plots
#
# - Categorical data plots
#
# - Distribution plots
#
# - Color themes
#
# - Multi-variable analysis

# %%
# E:\UDSUltimate2.0_repo\ultimateds20_venv>uv add seaborn

# %%
## 1. HIST PLOT 
# sns.histplot(df_quantity['Quantity'], bins=10, kde=False, color='skyblue')
# sns.histplot(df_quantity['Quantity'], bins=10, kde=True, color='skyblue')

# %%
# 2. sns.kdeplot() — KDE (smooth version of histogram)
# sns.kdeplot(df_quantity['Quantity'], fill=True, color='green')

# %%
## 3. BOX PLOT #####
# sns.boxplot(data = df_sample, x='Country', y='Revenue')
# sns.boxplot(data = df_sample)
# sns.boxplot(data = df_revenue_sample, x='Month', y='Revenue')

# %%
##  4.Categorical Data Visualization
## sns.barplot(x=top_countries.values, y=top_countries.index, palette='viridis')
## sns.barplot(x=top_countries.index,  y=top_countries.values,  palette='viridis', hue=top_countries.index)
## sns.barplot(x=top_countries.values,  y=top_countries.index, legend=False, palette='Spectral')

# %%
## 5. COUNT PLOT : # 2. Number of Transactions by Country 
sns.countplot(
    data=df_sample,
    x='Country',
    order = df_sample['Country'].value_counts().index
)

# Top 5 countries by number of transactions

# %%
### 6. BAR PLOT 
## sns.barplot(data=grouped, x='Month', y='Revenue', hue='Country')

# %%
## 7. SCATTER PLOT 
## sns.scatterplot(data=df_sample, x='Quantity', y='Revenue', hue='Country', alpha=0.6)

# %%
## 8. Pair Plot 
## sns.pairplot(df_sample[['Quantity', 'Price', 'Revenue']],diag_kind='kde')

# %%
## 9. HEATMAP() ---> COrrelation MATRIX
## sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
## 
sns.heatmap(corr_matrix, annot=True, cmap='crest', fmt='.2f', linewidths=0.5)

# %%
##  

## Line is for trend 
## IF i how mUCH ---> Comparision

## SEABON

## Co relatio Matrix : What it is?
