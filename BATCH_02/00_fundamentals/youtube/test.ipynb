# %%
import pandas as pd

# Read CSV
df = pd.read_csv("subscriptions.csv")

# Print all rows
display(df)
# Out:
#                       title                              subscription_id  \
# 0            Republic World  Q_Ha2Du0saXhDvSQl7wMbO-49Fe3xk3ix3nx_BNhY9I
# 1                CNN-News18  Q_Ha2Du0saXuWJGo5UsssSFixzGL7k01VtUfSAeGlrQ
# 2              Endless Love  Q_Ha2Du0saUdfSBKjfxoRpUdpG67m7gPECe1dXj2pHs
# 3                     Tilak  Q_Ha2Du0saWF1z_Rf5-95NrR6m-to6C9bxrAXxRSfcY
# 4           ChinmayaChannel  Q_Ha2Du0saXuWJGo5UsssRTPjys1sBFJXlPc9dqsteo
# 5               Pen  Bhakti  Q_Ha2Du0saXYcHaudThkszmv7gO8f6Q_aiw68MDMwOY
# 6   Dolly in New Zealand 🇳🇿  Q_Ha2Du0saXuWJGo5UsssVtwQn6RzUorUvj0VDlYNHE
# 7       Ak Education System  Q_Ha2Du0saUvZlCSPzIwiLZu-t6ighj_acvKS3uPMwQ
# 8                Brut India  Q_Ha2Du0saXYcHaudThkswTmUnBqVnEPY9TO3sU7ehk
# 9       S2 Shiksha Siddhant  Q_Ha2Du0saXYcHaudThksxcM9eOfNzBWyNVvDinZD7s
# 10             Leon van Zyl  Q_Ha2Du0saXuWJGo5UsssZs2rvOsuOJ4qj15mMHhdCk
# 11  Ananda Sangha Worldwide  Q_Ha2Du0saXuWJGo5UsssQ9SWKPbtirylubuXu3_byg
# ...
