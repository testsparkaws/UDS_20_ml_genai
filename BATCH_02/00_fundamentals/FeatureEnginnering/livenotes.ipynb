# %% [markdown]
# ## **FEature ENGINNERING**

# %%
print("ALLOKAY")
# Out:
# ALLOKAY

# %% [markdown]
# ## **DAY1: **

# %%
# Out:
# ALLOKAY

# %% [markdown]
# ## **DAY2: 25-APR**

# %% [markdown]
# ## **DAY 3: 26-APR**

# %%
"OKAY"

# y = mx + c

# %%
# How to u usually do revision
# how to check which columns are numerical columns in dataframe?

# %%
## Feature Engineering STEPS ##########
# 1. handling Missing Data 
   ## remove the columns 
   ## Imputing the missing values
# 2. Feature Selection
# 3. Handling Outliers

# %%
## Hanlding Outliers: 
  ## Outliers --> Exterme value

# %%
## Why care anout Outlier
## ML Models like Linear Regression is sensitive to outliers.
## Distance based models like KNN, SVM are also sensitive to outliers.

# %%
# what is good thing about outliers? 
# ans: outliers can be an indication of some interesting phenomenon,
#  they can also be a result of data entry errors or measurement errors.

# %%
######## Method to detect outliers ##########
# 0. Capping Method (Winsorization)
# 1. Z-Score Method
# 2. IQR Method
# 3. Visualization Method (Box Plot, Scatter Plot)
# 4. Statistical Tests (Grubbs' Test, Dixon's Q Test)
# 5. Machine Learning Methods (Isolation Forest, Local Outlier Factor)
# 6. Domain Knowledge (Using domain knowledge to identify outliers based 
# on the context of the data)
# 7. Clustering Methods (Using clustering algorithms to identify outliers
