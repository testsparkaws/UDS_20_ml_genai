# %%
### System Design problem statemen

## 2 GB --> RAM 
## 100 GB ---> storage 

## CSV File -----> 5 Million records ---> 5 * 10,00,000 --> Size ---> 8 GB 
## Store everything in .DB

# %%
# as there are 5 millions recodxs with 8 GB RAM
# chunk size can be 1 Millions 
# read the file 1 millions records , that can be chunk size 
# reate a database connection
# insert to db

# %%
open(.csv)
 ## dont use readline.._. it will read all the lines 
 ## we will use iterator

# %%
## Open (csv,r) as f 
 # for i in range(0,6):
    ## conn = 
    ## cursor = 
    ## cursor.insert
