# %%
## Python >>> Problem Statement >> Student Data 
  --> Store 
  --> Update 
  --> Delete 
  --> REad 


## File System --> Read / Write 
## python 

class Database:
   get_student_data()
   get_all_student_data()
   
   delete_student_data()
   delete_all_student_data()

   update_student_data()
   update_all_student_data()
