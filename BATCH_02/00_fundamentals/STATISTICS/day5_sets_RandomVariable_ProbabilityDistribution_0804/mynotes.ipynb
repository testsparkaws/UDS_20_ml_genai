# %%
# SETS

# %% [markdown]
# ## **8_APR**

# %%
### TOPIC COVERED ###
# Sets
# Random Variable
# Probaility Distribution

# %%
## Two Types of Random Variable 
# 1. Continous   ----->  Described by: PMF, CDF
# 2. Discreate   ----->  Described by: PDF, CDF

# %%
# PMF --> Probabilty Mass Function

# %%
# set ---> probability
