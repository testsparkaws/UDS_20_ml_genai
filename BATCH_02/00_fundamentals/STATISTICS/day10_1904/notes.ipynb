# %%
## Aagenda 
# https://www.sjsu.edu/faculty/gerstman/StatPrimer/t-table.pdf

# %% [markdown]
# Here's everything covered across **5 sections**:
#
# 1. **P-Value Recap & Two-Tail Extension** — one-tail (0.0668) vs two-tail (0.1336) calculation with annotated bell curve diagrams and a comparison table
#
# 2. **Confidence Interval** — the "park walk" intuition, CI formula (x̄ ± z*×SE), full 4-step worked example with a visual number line showing H₀=30 falling inside the interval
#
# 3. **T-Test** — when σ is unknown, Z-test vs T-test comparison table, T-distribution diagram showing how curves flatten at lower df, degrees of freedom explained, full lightbulb example (t = −2.12 vs critical 2.776 → fail to reject)
#
# 4. **Bayes' Theorem** — prior/likelihood/posterior/evidence diagram, formula, the rare disease example showing how a 99% accurate test still gives only 16.7% chance of being sick (with the 1000-person tree breakdown)
#
# 5. **Chi-Square Test** — why it's needed for categorical data, formula, full fruit snack example (Mango/Pineapple/Kiwi), χ²=9.8 vs critical 5.991 → reject H₀, annotated chi-square distribution diagram
