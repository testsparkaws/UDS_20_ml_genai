# %% [markdown]
# Here's your Lecture 9 notes PDF, beautifully formatted! 🎓
#
# It covers all **8 sections** from your notes:
#
# 1. **Z-Score** — the "universal translator", formula, worked height example (z=2 → 97th percentile)
# 2. **Central Limit Theorem** — population vs sample means, why n≥30 matters, bell curve diagram
# 3. **Standard Error** — SD vs SE comparison table + side-by-side visual showing SE is always narrower
# 4. **Z-Statistic** — how it differs from Z-score, full formula, caffeine energy drink scenario
# 5. **Significance Level (α)** — α table (0.05/0.01/0.10), critical values, 95% confidence curve diagram
# 6. **Hypothesis Testing** — H₀ vs H₁ court analogy, one-tailed vs two-tailed with annotated diagrams
# 7. **Full Worked Example** — 4-step delivery company test (Z_stat = 1.50 vs critical 1.645 → fail to reject)
# 8. **P-Value** — what it means, the golden rule (p < α → reject), p-value calculation for the same example
