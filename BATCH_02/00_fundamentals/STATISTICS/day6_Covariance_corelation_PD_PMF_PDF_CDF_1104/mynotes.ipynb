# %%
"ALLOKAY"
# Out:
# 'ALLOKAY'

# %%
day6_Covariance_corelation_PD_PMF_PDF_CDF

# %%
######## Topic Covered ####
# CoVariance
# CoRelation
# Probability Distribution

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## CORRELATION

# %%
# Q) Why We have caclulated tandard deviation by dividing by 2 (page 4)

# %%
### Understand NUmbers ---> make ur best Friends ---> u will see the magic

# %%
## Question 
# this relation only work with columns which has numbers or the columns with string or other data types

# %% [markdown]
# # **3.Probabilty Distribution**

# %%
# PMF ---> Probabilty Mass Fucntion
# PDF ---> Probabilty Density Function       ==>  Works with Continuous data
# CDF ---> Cumulative Distribution Function  ===> works with Discrete data

# %%
# Probability Distributions
#  ==> Discrete RV   → PMF (Probability Mass Function)    + CDF
#  ==> Continuous RV → PDF (Probability Density Function) + CDF

# %%
#Q) To calcualte area under the curve , are we first diving the bin_width , then again we are multiplying it with bin_widht

# %%
# towards Red ---> Positive 
# Towards BLUE ---> Negative 

# Q) usefulness of COlumns ?
# Drop the columns which is not usefulness

# BEst colreallation Value ---> -0.06

# %%
###

# %% [markdown]
# I can see all 11 pages of your new notes (11 April 2026) on Covariance, Correlation, PMF, CDF, and PDF. Let me build the PDF now.Your PDF for the 11 April notes is ready! Here's what's covered across all 4 sections:
#
# **§ 01 — Covariance** — definition, motivating example (live class vs completion rate), types (+ve/−ve/zero), full worked example with study hours vs marks (Cov = 16.67), second example with hours vs stress (negative cov), and the unit problem explanation
#
# **§ 02 — Correlation** — formula, normalization concept, full worked example (r = 1, perfect), interpretation table, and ML feature selection practical example (86% → 92% accuracy)
#
# **§ 03 — Probability Distributions** — PMF (dice, Python code, bar chart), CDF (step function, dice walkthrough, properties), PDF (why not PMF for continuous, 4-step PDF construction from heights data, area calculation, range queries)
#
# **§ 04 — Summary table** of all key formulas
#
# **6 charts** embedded — scatter plots, correlation matrix, PMF bar, CDF step function, PDF histogram, and CDF S-curve for heights.
