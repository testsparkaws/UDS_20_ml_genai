# %%
######## TOPIC COVERED #########
### Probability Distribution #######
# 1. Bernoulli
# 2. Binomial
# 3. Poisson
# 4. Exponential
# 5. Uniform

day7_Bernoulli_Binomial_Poisson_Exponential_Uniform

# %%
# Learn Mathemetics as mUch as possible

# %%
## Customer care ---- He has given one problem statement 
## Har cheez kjo ho rahi hai usko problem statement ko dekhogke to learn karoge life main ---<
