# %% [markdown]
# i want you to read the whole pdf and create a new pdf out of it , with beautifucation, please add concepts, example, and dont create tables where content overlaps

# %% [markdown]
# ## **Day5**

# %%
# GridSearchCV

# %% [markdown]
# ## 14-06: DAY6

# %% [markdown]
# ## **DAY9**
